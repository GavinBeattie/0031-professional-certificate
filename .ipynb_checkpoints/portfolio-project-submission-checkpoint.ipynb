# %% [markdown]
# # Portfolio project submission
# ## Packages

# %%
# GB: Packages:
# GB: From previous file:
import torch # GB: Contains torch.utils.data?
import torchvision
import torchvision.transforms as transforms
# GB: Added:
import cv2 # For img_loader. vs line below.
import numpy as np
from torchvision.datasets import ImageFolder # GB: For Helper Functions.
# GB: Ref.: https://pytorch.org/vision/main/generated/torchvision.datasets.ImageFolder.html
# GB: Ref.: https://discuss.pytorch.org/t/how-to-load-images-from-different-folders-in-the-same-batch/18942/6
print(torch.__version__) # GB: Added.

import torch.nn as nn
import torch.nn.functional as F

# GB: 3.
import torch.optim as optim
import time

# GB: 4.
from hyperopt import fmin, hp, tpe # GB: In alphabetical order.
from hyperopt import rand # GB: [2].
from hyperopt import Trials # GB: [2].
import matplotlib.pyplot as plt
import seaborn as sns # GB: Added.

# GB: 5
from cv2 import * # GB: Importing OpenCV library.
# Out:
# 2.1.0.post100

# %%
# GB: Suffix Structure:
# GB: _train
# GB: _validate # GB: NB Not used.
# GB: _test

# %% [markdown]
# ## Environment

# %%
torch.cuda.is_available()
# Out:
# False

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# GB: torch.cuda.get_device_name(0)
# GB: 'NVIDIA Tegra X1'

# %% [markdown]
# ## Data

# %%
# GB: Helper Functions:
def img_loader(filename):
    # GB: return cv2.imread(filename, cv2.IMREAD_GRAYSCALE)
    img = cv2.imread(filename, cv2.IMREAD_COLOR) # GB: Not cv2.IMREAD_UNCHANGED.
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

def img_folder(root):
    # GB: Changed from 3D to 1D, i.e. from (0.5, 0.5, 0.5) to (0.5,). NB The trailing comma might be important.
    # GB: Parameters: means and standard deviations.
    # transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]) # GB: Greyscale.
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]) # GB: Colour
    return ImageFolder(root=root, loader=img_loader, transform=transform)

# GB: Datasets:
# GB: folder_train = './grayscale/train/' # GB: Put in here to not get lost. Greyscale.
# GB: folder_test = './grayscale/test/' # GB: Put in here to not get lost. Greyscale.
folder_train = './rgb/train/' # GB: Put in here to not get lost. RGB.
folder_test = './rgb/test/' # GB: Put in here to not get lost. RGB.
dataset_train = img_folder(folder_train)
dataset_test = img_folder(folder_test)

# GB: Check:
array_train = np.array(dataset_train.classes)
array_test = np.array(dataset_test.classes)

if np.array_equal(array_train, array_test):
    print('Classes are equal', dataset_train.classes)
    classes = dataset_train.classes
else:
    print('Classes are not equal', dataset_train.classes, dataset_test.classes)
    classes = ['error']
# Out:
# Classes are equal ['bart_simpson', 'charles_montgomery_burns', 'homer_simpson', 'krusty_the_clown', 'lisa_simpson', 'marge_simpson', 'milhouse_van_houten', 'moe_szyslak', 'ned_flanders', 'principal_skinner']

# %%
# GB: Dataloaders:
if torch.cuda.is_available():
    num_workers = 4
else:
    num_workers = 0

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=100, shuffle=True, num_workers=num_workers)
dataloader_test  = torch.utils.data.DataLoader(dataset_test,  batch_size=100, shuffle=True, num_workers=num_workers)

# GB: Check:
# GB: Okay.

# %% [markdown]
# ## Modelling

# %%
# GB: Model:

# GB: Reserved for future hyperparameters (like space below):
space_future = {
    'dim_1': 29 * 27,
    'dim_2': 13 * 12,
    'dim_3': 5 * 4,
    'c_1': 20,
    'c_2': 4,
    'c_3': 2
}

# GB: Reserved for future parameters:
# GB: Could do as adapted or original LeNet?
# GB: And other controls switches. 

# GB: Start Boilerplate (PyTorch):
class Net(nn.Module):
    def __init__(self, name=None):
        # GB: For what each layer does see ...
        # GB: Ref.: https://pytorch.org/tutorials/beginner/blitz/neural_networks_tutorial.html
        super(Net, self).__init__()
        if name:
            self.name = name
        # GB: self.conv1 = nn.Conv2d(1, 6, 5) # self.conv1 = nn.Conv2d(1, 10, 5) # GB: Greyscale.
        self.conv1 = nn.Conv2d(3, 6, 5) # self.conv1 = nn.Conv2d(1, 10, 5) # GB: Colour.
        self.pool = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)) # GB: vs 2, 2. # self.pool = nn.MaxPool2d((3, 2), 2)
        self.conv2 = nn.Conv2d(6, 16, 5) # self.conv2 = nn.Conv2d(10, 16, 5)
        self.fc1 = nn.Linear(16 * 4 * 4, 120) # self.fc1 = nn.Linear(192, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        
        # compute the total number of parameters
        total_params = sum(p.numel() for p in self.parameters() if p.requires_grad)
        print(self.name + ': total params:', total_params)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 4 * 4) # x = x.view(-1, 192)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

if torch.cuda.is_available():
    model = Net(name='GavNet-1').to(device)
else:
    model = Net(name='GavNet-1') # GB: Changed from net to model for clarity.

print(model) # GB: Added.
# GB: End Boilerplate (PyTorch).
# Out:
# GavNet-1: total params: 44726
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=256, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# # Training and testing

# %%
# %%
# GB: Packages 3.

# GB: Train Function:
def train(params, *args, **kwargs):
    # GB: dataloader_train and model previously declared.
    # GB: Hyperparameters:
    lr, momentum, epochs = params['lr'], params['momentum'], params['epochs']
    lr = 0.001 # GB: Manual overide.
    momentum = 0.9 # GB: Manual overide.
    epochs = 2 # GB: Manual overide.
    # GB: Parameters:
    

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum) # GB: Changed from net to model.
    # GB: Ref.: https://pytorch.org/docs/stable/generated/torch.optim.SGD.html

    start = time.time()

    for epoch in range(epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(dataloader_train, 0):
            # get the inputs; data is a list of [inputs, labels] where from?
            # GB: inputs, labels = data
            if torch.cuda.is_available():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
            else:
                inputs, labels = data

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics # GB: Adjust for expected data.
            running_loss += loss.item()
            if i % 20 == 19:    # print every 2000 mini-batches # GB: Needs tweeked for dataset. # GB: Chnaged from 2000, 1999
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 20)) # GB: Chnaged from 20.
                running_loss = 0.0

    end = time.time()
    print('training time ', end - start)
    print('Finished Training')

# %%
def test(params, *args, **kwargs):
    # GB: classes and dataloader_test and model previously declared.
    # GB: Hyperparameters:
    # GB: Spare.
    correct = 0
    total = 0
    with torch.no_grad():
        tmp = 0 # GB: Temporary metric.
        for data in dataloader_test:
            tmp += 1 
            # GB: images, labels = data
            if torch.cuda.is_available():
                images, labels = data
                images, labels = images.to(device), labels.to(device)
            else:
                images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('runs of batches', tmp)
    print('Accuracy of the network on the 10000 test images: %d %%' % (
        100 * correct / total))

    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in dataloader_test:
            # GB: images, labels = data
            if torch.cuda.is_available():
                images, labels = data
                images, labels = images.to(device), labels.to(device)
            else:
                images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            c = (predicted == labels).squeeze()
            for i in range(4):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    for i in range(10):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

    return round(1 - (correct / total), 6) # GB: Six decimal places aligned to Capstone project.

# %% [markdown]
# ## Hyperopt

# %% [markdown]
# ### History

# %%
# GB: [2].
tpe_trials = Trials()
# GB: rand_trials = Trials()

# %% [markdown]
# ### Optimisation

# %%
# GB: At this point it had finished running. Make replacement for main(())
# GB: Inspired by [2]
# GB: https://github.com/hyperopt/hyperopt/wiki/FMin
# GB: https://github.com/hyperopt/hyperopt/wiki/FMin#11-the-simplest-case
# GB: Better ref than previous line
# GB: https://hyperopt.github.io/hyperopt/tutorials/02.MultipleParameterTutorial/

# GB: Trying... $ conda install intel::hyperopt # GB: Failed.
# GB: Trying... $ pip install hyperopt # GB: Passed with errors.
# GB: Come back to.

# GB: Packages 4.

# Helper Function:
def run_model(params):
    train(params)
    test_result = test(params)
    return test_result

# GB: Hyperparameters:
space = {
    'lr': hp.uniform('lr', 0.09, 0.1), # GB: Defaults: 0.001(PyTorch)-0.1.
    'momentum': hp.uniform('momentum', 0.4, 0.5), # GB: Defaults: 0(PyTorch)-0.9.
    'epochs': hp.uniformint('epochs', 1, 10) # GB: Defaults: 1-5(PyTorch)-10.
}

best = fmin(fn=run_model,
            space=space,
            algo=tpe.suggest,
            trials=tpe_trials, # GB: [2].
            max_evals=100) # GB: Defaults: 1(test)-100(max for now).

print(best)
# GB: 100%|████████████████████| 100/100 [08:35<00:00,  5.15s/trial, best loss: 0.302]
# GB: {'epochs': 1.0, 'lr': 0.0970507895380236, 'momentum': 0.43910901647510114}
# Out:
# [1,    20] loss: 2.304
# [1,    40] loss: 2.306
# [1,    60] loss: 2.305
# [1,    80] loss: 2.304
# [2,    20] loss: 2.304
# [2,    40] loss: 2.305
# [2,    60] loss: 2.303
# [2,    80] loss: 2.305
# training time
# 6.322038650512695
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 12 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 42 %
# Accuracy of lisa_simpson :  0 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders : 15 %
# Accuracy of principal_skinner : 88 %
# [1,    20] loss: 2.303
# [1,    40] loss: 2.303
# [1,    60] loss: 2.304
# [1,    80] loss: 2.303
# [2,    20] loss: 2.303
# [2,    40] loss: 2.302
# [2,    60] loss: 2.302
# [2,    80] loss: 2.303
# training time
# 4.018659830093384
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 14 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson :  0 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders : 33 %
# Accuracy of principal_skinner : 37 %
# [1,    20] loss: 2.302
# [1,    40] loss: 2.301
# [1,    60] loss: 2.302
# [1,    80] loss: 2.302
# [2,    20] loss: 2.301
# [2,    40] loss: 2.302
# [2,    60] loss: 2.300
# [2,    80] loss: 2.301
# training time
# 4.308857202529907
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 15 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 77 %
# Accuracy of lisa_simpson :  0 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders : 33 %
# Accuracy of principal_skinner : 28 %
# [1,    20] loss: 2.301
# [1,    40] loss: 2.300
# [1,    60] loss: 2.300
# [1,    80] loss: 2.300
# [2,    20] loss: 2.300
# [2,    40] loss: 2.300
# [2,    60] loss: 2.299
# [2,    80] loss: 2.299
# training time
# 4.272124767303467
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 15 %
# Accuracy of bart_simpson : 25 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson :  0 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders : 25 %
# Accuracy of principal_skinner : 25 %
# [1,    20] loss: 2.299
# [1,    40] loss: 2.299
# [1,    60] loss: 2.298
# [1,    80] loss: 2.297
# [2,    20] loss: 2.298
# [2,    40] loss: 2.297
# [2,    60] loss: 2.297
# [2,    80] loss: 2.295
# training time
# 4.41968297958374
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 16 %
# Accuracy of bart_simpson : 16 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson :  9 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson :  0 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner : 10 %
# [1,    20] loss: 2.297
# [1,    40] loss: 2.296
# [1,    60] loss: 2.295
# [1,    80] loss: 2.293
# [2,    20] loss: 2.294
# [2,    40] loss: 2.293
# [2,    60] loss: 2.292
# [2,    80] loss: 2.293
# training time
# 4.377161026000977
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 18 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson : 14 %
# Accuracy of krusty_the_clown : 90 %
# Accuracy of lisa_simpson : 80 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders : 12 %
# Accuracy of principal_skinner : 14 %
# [1,    20] loss: 2.291
# [1,    40] loss: 2.290
# [1,    60] loss: 2.291
# [1,    80] loss: 2.289
# [2,    20] loss: 2.289
# [2,    40] loss: 2.287
# [2,    60] loss: 2.285
# [2,    80] loss: 2.283
# training time
# 4.383986949920654
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 16 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns :  0 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 75 %
# Accuracy of lisa_simpson : 100 %
# Accuracy of marge_simpson : 14 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner : 20 %
# [1,    20] loss: 2.283
# [1,    40] loss: 2.281
# [1,    60] loss: 2.279
# [1,    80] loss: 2.280
# [2,    20] loss: 2.277
# [2,    40] loss: 2.274
# [2,    60] loss: 2.270
# [2,    80] loss: 2.266
# training time
# 4.29371976852417
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 14 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns : 18 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 14 %
# Accuracy of lisa_simpson : 85 %
# Accuracy of marge_simpson :  0 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  9 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 2.265
# [1,    40] loss: 2.264
# [1,    60] loss: 2.257
# [1,    80] loss: 2.251
# [2,    20] loss: 2.250
# [2,    40] loss: 2.237
# [2,    60] loss: 2.239
# [2,    80] loss: 2.226
# training time
# 4.0444769859313965
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 17 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns : 62 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown :  0 %
# Accuracy of lisa_simpson : 66 %
# Accuracy of marge_simpson : 44 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 2.227
# [1,    40] loss: 2.213
# [1,    60] loss: 2.199
# [1,    80] loss: 2.190
# [2,    20] loss: 2.183
# [2,    40] loss: 2.170
# [2,    60] loss: 2.147
# [2,    80] loss: 2.119
# training time
# 4.324764966964722
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 22 %
# Accuracy of bart_simpson : 50 %
# Accuracy of charles_montgomery_burns : 44 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown :  0 %
# Accuracy of lisa_simpson : 42 %
# Accuracy of marge_simpson : 100 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 2.124
# [1,    40] loss: 2.094
# [1,    60] loss: 2.106
# [1,    80] loss: 2.075
# [2,    20] loss: 2.069
# [2,    40] loss: 2.058
# [2,    60] loss: 2.055
# [2,    80] loss: 2.041
# training time
# 4.188941955566406
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 26 %
# Accuracy of bart_simpson : 37 %
# Accuracy of charles_montgomery_burns : 45 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 25 %
# Accuracy of lisa_simpson : 45 %
# Accuracy of marge_simpson : 71 %
# Accuracy of milhouse_van_houten :  0 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 2.038
# [1,    40] loss: 2.037
# [1,    60] loss: 2.052
# [1,    80] loss: 2.000
# [2,    20] loss: 2.004
# [2,    40] loss: 2.021
# [2,    60] loss: 2.004
# [2,    80] loss: 1.985
# training time
# 4.344598054885864
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 29 %
# Accuracy of bart_simpson : 25 %
# Accuracy of charles_montgomery_burns : 33 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 76 %
# Accuracy of lisa_simpson : 42 %
# Accuracy of marge_simpson : 60 %
# Accuracy of milhouse_van_houten : 16 %
# Accuracy of moe_szyslak : 25 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 1.977
# [1,    40] loss: 1.986
# [1,    60] loss: 1.984
# [1,    80] loss: 1.964
# [2,    20] loss: 1.952
# [2,    40] loss: 1.944
# [2,    60] loss: 1.954
# [2,    80] loss: 1.939
# training time
# 4.365555047988892
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 33 %
# Accuracy of bart_simpson : 37 %
# Accuracy of charles_montgomery_burns : 57 %
# Accuracy of homer_simpson : 28 %
# Accuracy of krusty_the_clown : 70 %
# Accuracy of lisa_simpson : 12 %
# Accuracy of marge_simpson : 55 %
# Accuracy of milhouse_van_houten : 50 %
# Accuracy of moe_szyslak : 12 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 1.939
# [1,    40] loss: 1.924
# [1,    60] loss: 1.929
# [1,    80] loss: 1.905
# [2,    20] loss: 1.911
# [2,    40] loss: 1.867
# [2,    60] loss: 1.913
# [2,    80] loss: 1.896
# training time
# 4.226757764816284
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 35 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns : 44 %
# Accuracy of homer_simpson : 16 %
# Accuracy of krusty_the_clown : 68 %
# Accuracy of lisa_simpson : 28 %
# Accuracy of marge_simpson : 50 %
# Accuracy of milhouse_van_houten : 50 %
# Accuracy of moe_szyslak : 25 %
# Accuracy of ned_flanders : 14 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 1.872
# [1,    40] loss: 1.870
# [1,    60] loss: 1.898
# [1,    80] loss: 1.864
# [2,    20] loss: 1.859
# [2,    40] loss: 1.869
# [2,    60] loss: 1.866
# [2,    80] loss: 1.846
# training time
# 4.594659805297852
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 33 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns : 50 %
# Accuracy of homer_simpson : 28 %
# Accuracy of krusty_the_clown : 85 %
# Accuracy of lisa_simpson :  0 %
# Accuracy of marge_simpson : 42 %
# Accuracy of milhouse_van_houten : 37 %
# Accuracy of moe_szyslak :  0 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner : 10 %
# [1,    20] loss: 1.829
# [1,    40] loss: 1.866
# [1,    60] loss: 1.857
# [1,    80] loss: 1.815
# [2,    20] loss: 1.841
# [2,    40] loss: 1.831
# [2,    60] loss: 1.820
# [2,    80] loss: 1.803
# training time
# 4.710216999053955
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 38 %
# Accuracy of bart_simpson : 28 %
# Accuracy of charles_montgomery_burns : 18 %
# Accuracy of homer_simpson : 20 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 55 %
# Accuracy of marge_simpson : 100 %
# Accuracy of milhouse_van_houten : 22 %
# Accuracy of moe_szyslak : 33 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner : 50 %
# [1,    20] loss: 1.844
# [1,    40] loss: 1.798
# [1,    60] loss: 1.799
# [1,    80] loss: 1.788
# [2,    20] loss: 1.801
# [2,    40] loss: 1.804
# [2,    60] loss: 1.796
# [2,    80] loss: 1.774
# training time
# 4.449270009994507
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 40 %
# Accuracy of bart_simpson : 57 %
# Accuracy of charles_montgomery_burns : 20 %
# Accuracy of homer_simpson : 30 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 33 %
# Accuracy of marge_simpson : 72 %
# Accuracy of milhouse_van_houten : 36 %
# Accuracy of moe_szyslak : 36 %
# Accuracy of ned_flanders : 28 %
# Accuracy of principal_skinner :  0 %
# [1,    20] loss: 1.771
# [1,    40] loss: 1.766
# [1,    60] loss: 1.759
# [1,    80] loss: 1.766
# [2,    20] loss: 1.732
# [2,    40] loss: 1.798
# [2,    60] loss: 1.755
# [2,    80] loss: 1.702
# training time
# 4.281856060028076
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 41 %
# Accuracy of bart_simpson :  0 %
# Accuracy of charles_montgomery_burns : 33 %
# Accuracy of homer_simpson : 33 %
# Accuracy of krusty_the_clown : 70 %
# Accuracy of lisa_simpson : 16 %
# Accuracy of marge_simpson : 78 %
# Accuracy of milhouse_van_houten : 75 %
# Accuracy of moe_szyslak : 28 %
# Accuracy of ned_flanders : 16 %
# Accuracy of principal_skinner : 11 %
# [1,    20] loss: 1.736
# [1,    40] loss: 1.736
# [1,    60] loss: 1.702
# [1,    80] loss: 1.753
# [2,    20] loss: 1.714
# [2,    40] loss: 1.718
# [2,    60] loss: 1.680
# [2,    80] loss: 1.734
# training time
# 4.561259031295776
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 40 %
# Accuracy of bart_simpson : 25 %
# Accuracy of charles_montgomery_burns : 71 %
# Accuracy of homer_simpson : 16 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 33 %
# Accuracy of marge_simpson : 70 %
# Accuracy of milhouse_van_houten : 42 %
# Accuracy of moe_szyslak : 27 %
# Accuracy of ned_flanders :  0 %
# Accuracy of principal_skinner : 60 %
# [1,    20] loss: 1.680
# [1,    40] loss: 1.681
# [1,    60] loss: 1.705
# [1,    80] loss: 1.709
# [2,    20] loss: 1.672
# [2,    40] loss: 1.664
# [2,    60] loss: 1.683
# [2,    80] loss: 1.696
# training time
# 4.24715781211853
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 44 %
# Accuracy of bart_simpson : 40 %
# Accuracy of charles_montgomery_burns : 40 %
# Accuracy of homer_simpson : 66 %
# Accuracy of krusty_the_clown : 83 %
# Accuracy of lisa_simpson : 12 %
# Accuracy of marge_simpson : 66 %
# Accuracy of milhouse_van_houten : 45 %
# Accuracy of moe_szyslak : 12 %
# Accuracy of ned_flanders : 28 %
# Accuracy of principal_skinner : 37 %
# [1,    20] loss: 1.653
# [1,    40] loss: 1.637
# [1,    60] loss: 1.704
# [1,    80] loss: 1.628
# [2,    20] loss: 1.662
# [2,    40] loss: 1.618
# [2,    60] loss: 1.615
# [2,    80] loss: 1.652
# training time
# 4.352553844451904
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 45 %
# Accuracy of bart_simpson :  8 %
# Accuracy of charles_montgomery_burns : 33 %
# Accuracy of homer_simpson : 33 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 33 %
# Accuracy of marge_simpson : 80 %
# Accuracy of milhouse_van_houten : 12 %
# Accuracy of moe_szyslak : 64 %
# Accuracy of ned_flanders : 33 %
# Accuracy of principal_skinner : 36 %
# [1,    20] loss: 1.648
# [1,    40] loss: 1.625
# [1,    60] loss: 1.616
# [1,    80] loss: 1.602
# [2,    20] loss: 1.613
# [2,    40] loss: 1.606
# [2,    60] loss: 1.606
# [2,    80] loss: 1.589
# training time
# 4.522886753082275
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 45 %
# Accuracy of bart_simpson : 16 %
# Accuracy of charles_montgomery_burns : 25 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 66 %
# Accuracy of lisa_simpson : 62 %
# Accuracy of marge_simpson : 60 %
# Accuracy of milhouse_van_houten : 22 %
# Accuracy of moe_szyslak : 50 %
# Accuracy of ned_flanders : 25 %
# Accuracy of principal_skinner : 16 %
# [1,    20] loss: 1.613
# [1,    40] loss: 1.576
# [1,    60] loss: 1.588
# [1,    80] loss: 1.587
# [2,    20] loss: 1.608
# [2,    40] loss: 1.564
# [2,    60] loss: 1.569
# [2,    80] loss: 1.578
# training time
# 4.263238906860352
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 46 %
# Accuracy of bart_simpson : 35 %
# Accuracy of charles_montgomery_burns : 57 %
# Accuracy of homer_simpson :  0 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 40 %
# Accuracy of marge_simpson : 70 %
# Accuracy of milhouse_van_houten : 20 %
# Accuracy of moe_szyslak : 62 %
# Accuracy of ned_flanders : 55 %
# Accuracy of principal_skinner : 20 %
# [1,    20] loss: 1.534
# [1,    40] loss: 1.535
# [1,    60] loss: 1.595
# [1,    80] loss: 1.584
# [2,    20] loss: 1.519
# [2,    40] loss: 1.548
# [2,    60] loss: 1.558
# [2,    80] loss: 1.559
# training time
# 4.296878099441528
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 47 %
# Accuracy of bart_simpson : 11 %
# Accuracy of charles_montgomery_burns : 16 %
# Accuracy of homer_simpson : 37 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 63 %
# Accuracy of marge_simpson : 75 %
# Accuracy of milhouse_van_houten : 37 %
# Accuracy of moe_szyslak : 36 %
# Accuracy of ned_flanders : 44 %
# Accuracy of principal_skinner : 30 %
# [1,    20] loss: 1.535
# [1,    40] loss: 1.527
# [1,    60] loss: 1.553
# [1,    80] loss: 1.527
# [2,    20] loss: 1.530
# [2,    40] loss: 1.504
# [2,    60] loss: 1.511
# [2,    80] loss: 1.533
# training time
# 4.310718059539795
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 48 %
# Accuracy of bart_simpson : 50 %
# Accuracy of charles_montgomery_burns : 16 %
# Accuracy of homer_simpson : 41 %
# Accuracy of krusty_the_clown : 66 %
# Accuracy of lisa_simpson : 33 %
# ...
# Accuracy of milhouse_van_houten : 62 %
# Accuracy of moe_szyslak : 90 %
# Accuracy of ned_flanders : 100 %
# Accuracy of principal_skinner : 50 %
# [1,    20] loss: 0.260
# [1,    40] loss: 0.297
# [1,    60] loss: 0.317
# [1,    80] loss: 0.326
# [2,    20] loss: 0.309
# [2,    40] loss: 0.288
# [2,    60] loss: 0.272
# [2,    80] loss: 0.313
# training time
# 4.384706974029541
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 67 %
# Accuracy of bart_simpson : 50 %
# Accuracy of charles_montgomery_burns : 47 %
# Accuracy of homer_simpson : 50 %
# Accuracy of krusty_the_clown : 66 %
# Accuracy of lisa_simpson : 40 %
# Accuracy of marge_simpson : 85 %
# Accuracy of milhouse_van_houten : 66 %
# Accuracy of moe_szyslak : 60 %
# Accuracy of ned_flanders : 50 %
# Accuracy of principal_skinner : 42 %
# [1,    20] loss: 0.239
# [1,    40] loss: 0.302
# [1,    60] loss: 0.309
# [1,    80] loss: 0.290
# [2,    20] loss: 0.271
# [2,    40] loss: 0.274
# [2,    60] loss: 0.310
# [2,    80] loss: 0.296
# training time
# 4.688277959823608
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 68 %
# Accuracy of bart_simpson : 44 %
# Accuracy of charles_montgomery_burns : 71 %
# Accuracy of homer_simpson : 14 %
# Accuracy of krusty_the_clown : 80 %
# Accuracy of lisa_simpson : 71 %
# Accuracy of marge_simpson : 66 %
# Accuracy of milhouse_van_houten : 66 %
# Accuracy of moe_szyslak : 100 %
# Accuracy of ned_flanders : 50 %
# Accuracy of principal_skinner : 77 %
# [1,    20] loss: 0.268
# [1,    40] loss: 0.269
# [1,    60] loss: 0.276
# [1,    80] loss: 0.278
# [2,    20] loss: 0.260
# [2,    40] loss: 0.254
# [2,    60] loss: 0.290
# [2,    80] loss: 0.322
# training time
# 4.179643869400024
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 66 %
# Accuracy of bart_simpson : 55 %
# Accuracy of charles_montgomery_burns : 100 %
# Accuracy of homer_simpson : 60 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 16 %
# Accuracy of marge_simpson : 62 %
# Accuracy of milhouse_van_houten : 60 %
# Accuracy of moe_szyslak : 45 %
# Accuracy of ned_flanders : 90 %
# Accuracy of principal_skinner : 100 %
# [1,    20] loss: 0.263
# [1,    40] loss: 0.254
# [1,    60] loss: 0.272
# [1,    80] loss: 0.317
# [2,    20] loss: 0.272
# [2,    40] loss: 0.258
# [2,    60] loss: 0.245
# [2,    80] loss: 0.295
# training time
# 4.368438005447388
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 68 %
# Accuracy of bart_simpson : 28 %
# Accuracy of charles_montgomery_burns : 70 %
# Accuracy of homer_simpson : 60 %
# Accuracy of krusty_the_clown : 75 %
# Accuracy of lisa_simpson : 37 %
# Accuracy of marge_simpson : 90 %
# Accuracy of milhouse_van_houten : 60 %
# Accuracy of moe_szyslak : 83 %
# Accuracy of ned_flanders : 80 %
# Accuracy of principal_skinner : 80 %
# [1,    20] loss: 0.208
# [1,    40] loss: 0.252
# [1,    60] loss: 0.263
# [1,    80] loss: 0.272
# [2,    20] loss: 0.262
# [2,    40] loss: 0.236
# [2,    60] loss: 0.242
# [2,    80] loss: 0.237
# training time
# 4.3126609325408936
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 69 %
# Accuracy of bart_simpson : 71 %
# Accuracy of charles_montgomery_burns : 61 %
# Accuracy of homer_simpson : 54 %
# Accuracy of krusty_the_clown : 83 %
# Accuracy of lisa_simpson : 83 %
# Accuracy of marge_simpson : 83 %
# Accuracy of milhouse_van_houten : 66 %
# Accuracy of moe_szyslak : 75 %
# Accuracy of ned_flanders : 81 %
# Accuracy of principal_skinner : 66 %
# [1,    20] loss: 0.178
# [1,    40] loss: 0.203
# [1,    60] loss: 0.246
# [1,    80] loss: 0.222
# [2,    20] loss: 0.218
# [2,    40] loss: 0.227
# [2,    60] loss: 0.226
# [2,    80] loss: 0.246
# training time
# 4.224874019622803
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 68 %
# Accuracy of bart_simpson : 60 %
# Accuracy of charles_montgomery_burns : 75 %
# Accuracy of homer_simpson : 57 %
# Accuracy of krusty_the_clown : 33 %
# Accuracy of lisa_simpson : 100 %
# Accuracy of marge_simpson : 91 %
# Accuracy of milhouse_van_houten : 66 %
# Accuracy of moe_szyslak : 60 %
# Accuracy of ned_flanders : 77 %
# Accuracy of principal_skinner : 77 %
# [1,    20] loss: 0.170
# [1,    40] loss: 0.200
# [1,    60] loss: 0.231
# [1,    80] loss: 0.300
# [2,    20] loss: 0.201
# [2,    40] loss: 0.209
# [2,    60] loss: 0.222
# [2,    80] loss: 0.280
# training time
# 4.29780387878418
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 68 %
# Accuracy of bart_simpson : 50 %
# Accuracy of charles_montgomery_burns : 87 %
# Accuracy of homer_simpson : 60 %
# Accuracy of krusty_the_clown : 92 %
# Accuracy of lisa_simpson : 40 %
# Accuracy of marge_simpson : 100 %
# Accuracy of milhouse_van_houten : 66 %
# Accuracy of moe_szyslak : 75 %
# Accuracy of ned_flanders : 56 %
# Accuracy of principal_skinner : 70 %
# [1,    20] loss: 0.183
# [1,    40] loss: 0.244
# [1,    60] loss: 0.251
# [1,    80] loss: 0.225
# [2,    20] loss: 0.191
# [2,    40] loss: 0.216
# [2,    60] loss: 0.202
# [2,    80] loss: 0.250
# training time
# 4.199864625930786
# Finished Training
# runs of batches
# 20
# Accuracy of the network on the 10000 test images: 66 %
# Accuracy of bart_simpson : 66 %
# Accuracy of charles_montgomery_burns : 62 %
# Accuracy of homer_simpson : 50 %
# Accuracy of krusty_the_clown : 100 %
# Accuracy of lisa_simpson : 50 %
# Accuracy of marge_simpson : 85 %
# Accuracy of milhouse_van_houten : 72 %
# Accuracy of moe_szyslak : 66 %
# Accuracy of ned_flanders : 60 %
# Accuracy of principal_skinner : 87 %
# 100%|███████████████████| 100/100 [08:52<00:00,  5.32s/trial, best loss: 0.3045]
# {'epochs': 8.0, 'lr': 0.09287075751778465, 'momentum': 0.4907924944637166}

# %%
# GB: Manual overide, if needed.
"""
space_best = {
    'lr': 0.090005,
    'momentum': 0.417016,
    'epochs': 8
}

run_model(space_best)
"""
# Out:
# "\nspace_best = {\n    'lr': 0.090005,\n    'momentum': 0.417016,\n    'epochs': 8\n}\n\nrun_model(space_best)\n"

# %% [markdown]
# ### Save/Load Entire Model/State Dictionary

# %%
# Ref.: https://pytorch.org/tutorials/beginner/saving_loading_models.html#save-load-entire-model
# Ref.: https://pytorch.org/tutorials/beginner/saving_loading_models.html#saving-loading-model-for-inference
path = './models/p-p-s-model-2024-06-03.pth'
path_2 = './models/p-p-s-state_dict-2024-06-03.pth'

# %%
torch.save(model, path)
torch.save(model.state_dict(), path_2)

# %%
# GB: If needed, uncomment:
# GB: model = torch.load(path)
# GB: model.eval()

# %%
# GB: If needed, uncomment:
# GB: model.load_state_dict(torch.load(path_2))
# GB: model.eval()

# %%
# GB: Probably better to save Hyperopt trials results.

# %% [markdown]
# ### Results

# %%
# GB: print(tpe_trials.results) # GB: Structure:
# GB: [{'loss': 0.8815, 'status': 'ok'}, {'loss': 0.8795, 'status': 'ok'}]
# GB: print(tpe_trials.idxs_vals) # GB: Structure:
# GB: ({'epochs': [0, 1], 'lr': [0, 1], 'momentum': [0, 1]},
# GB: {'epochs': [3.0, 4.0], 'lr': [0.052348024461833335, 0.06397292349002275], 'momentum': [0.21221118519166077, 0.35153211496086006]})

# %%
import pandas as pd
tpe_results = pd.DataFrame({'loss': [x['loss'] for x in tpe_trials.results], # GB: Borrowed from [2], list.
                            'iteration': tpe_trials.idxs_vals[0]['epochs'], # GB: Object with index 0 and any key.
                            'lr': tpe_trials.idxs_vals[1]['lr'], # GB: Object with index 1 and any key='lr'.
                            'momentum': tpe_trials.idxs_vals[1]['momentum'], # GB: Object with index 1 and any key='momentum'.
                            'epoch': tpe_trials.idxs_vals[1]['epochs']}) # GB: Object with index 1 and any key='momentum'.

tpe_results.head()
# Out:
#      loss  iteration        lr  momentum  epoch
# 0  0.8740          0  0.091492  0.487953    5.0
# 1  0.8580          1  0.093759  0.437292    8.0
# 2  0.8500          2  0.099807  0.469193    6.0
# 3  0.8485          3  0.090879  0.400512    2.0
# 4  0.8360          4  0.097844  0.483302    3.0

# %%
# GB: From Capstone project function 3:
plt.figure(figsize=(6, 6), dpi=80)
sns.pairplot(tpe_results, diag_kind='hist', corner=True, hue='loss', palette='coolwarm')
plt.show()
# Out:
# /Users/gavinbeattie/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gavinbeattie/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gavinbeattie/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/gavinbeattie/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# GB: Adapted from ref.: IMP-PCMLAI-M22-cifar10_tutorial

# functions to show an image
def imshow(img):
    img = (img * 0.5) + 0.5 # GB: Unnormalise * sd - mean.
    npimg = img.numpy() # GB: Converts a tensor object into an numpy.ndarray object.
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(dataloader_test)
# GB: images, labels = next(dataiter) # GB: Changed from .next().
if torch.cuda.is_available():
    images, labels = next(dataiter)
    images, labels = images.to(device), labels.to(device)
else:
    images, labels = next(dataiter)
n = 8 # GB: Added.
images_n = images[:n] # GB: Added.
labels_n = labels[:n] # GB: Added.

# print images
imshow(torchvision.utils.make_grid(images_n.cpu()))
print('Ground Truth: ', ' '.join('%5s' % classes[labels_n[j]] for j in range(n)))

outputs = model(images)

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(n)))
# Out:
# Ground Truth:  milhouse_van_houten milhouse_van_houten krusty_the_clown bart_simpson bart_simpson marge_simpson lisa_simpson marge_simpson
# Predicted:  charles_montgomery_burns milhouse_van_houten principal_skinner bart_simpson bart_simpson marge_simpson ned_flanders marge_simpson

# %% [markdown]
# ### The final chapter!

# %%
# https://www.geeksforgeeks.org/how-to-capture-a-image-from-webcam-in-python/
# https://gist.github.com/Luxato/384a7c8a6bfdeba09d54cb5bd6b2c9fb

def img_capture(x, img):
    img_resized_sml = cv2.resize(img, (28, 28))
    img_resized_lrg = cv2.resize(img, (280, 280))
    img_resized_sml_rgb = cv2.cvtColor(img_resized_sml, cv2.COLOR_BGR2RGB)
    img_resized_lrg_rgb = cv2.cvtColor(img_resized_lrg, cv2.COLOR_BGR2RGB)
    img_plot_sml = plt.imshow(img_resized_sml_rgb)
    img_plot_lrg = plt.imshow(img_resized_lrg_rgb)
    plt.show()
    image_tmp_sml = './tmp/new/capture_' + str(i) + '.jpg'
    cv2.imwrite(image_tmp_sml, img_resized_sml)
    # GB: return # GB: Reserved for future use.

# GB: Initialise the camera:
cam_port = 0
cam = VideoCapture(cam_port)

# GB: Read input from the camera:
time.sleep(0.5) # GB: Wait 500 miliseconds.
result, image = cam.read()
n = 8

# GB: Follow image loader pipeline.
if result:
    for i in range(n):
        # GB: Quick and dirty:
        print('Taking picture ' + str(i + 1) + ' in 3...')
        time.sleep(1.0) # GB: Wait 500 miliseconds.
        print('Taking picture ' + str(i + 1) + ' in 2...')
        time.sleep(1.0) # GB: Wait 500 miliseconds.
        print('Taking picture ' + str(i + 1) + ' in 1...')
        time.sleep(1.0) # GB: Wait 500 miliseconds.
        print('Taking picture ' + str(i + 1) + '')
        (result, image) = cam.read()
        img_capture(i, image)
        time.sleep(1.0) # GB: Wait 500 miliseconds.
    cam.release()
else:
    print('No image detected. Please check camera and try again.')
# Out:
# Taking picture 1 in 3...
# Taking picture 1 in 2...
# Taking picture 1 in 1...
# Taking picture 1
# Taking picture 2 in 3...
# Taking picture 2 in 2...
# Taking picture 2 in 1...
# Taking picture 2
# Taking picture 3 in 3...
# Taking picture 3 in 2...
# Taking picture 3 in 1...
# Taking picture 3
# Taking picture 4 in 3...
# Taking picture 4 in 2...
# Taking picture 4 in 1...
# Taking picture 4
# Taking picture 5 in 3...
# Taking picture 5 in 2...
# Taking picture 5 in 1...
# Taking picture 5
# Taking picture 6 in 3...
# Taking picture 6 in 2...
# Taking picture 6 in 1...
# Taking picture 6
# Taking picture 7 in 3...
# Taking picture 7 in 2...
# Taking picture 7 in 1...
# Taking picture 7
# Taking picture 8 in 3...
# Taking picture 8 in 2...
# Taking picture 8 in 1...
# Taking picture 8

# %%
folder_new = './tmp/'
dataset_new = img_folder(folder_new)
# n = 8 # GB: From cell above.
dataloader_new = torch.utils.data.DataLoader(dataset_new, batch_size=n, shuffle=True, num_workers=num_workers)

# %%
# GB: Duplicate of cell above.

# GB: Adapted from ref.: IMP-PCMLAI-M22-cifar10_tutorial

# functions to show an image
def imshow(img):
    img = (img * 0.5) + 0.5 # GB: Unnormalise * sd - mean.
    npimg = img.numpy() # GB: Converts a tensor object into an numpy.ndarray object.
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(dataloader_new)
# GB: images, labels = next(dataiter) # GB: Changed from .next().
if torch.cuda.is_available():
    images, labels = next(dataiter)
    images, labels = images.to(device), labels.to(device)
else:
    images, labels = next(dataiter)
# n = 8 # GB: From cell above.
images_n = images[:n] # GB: Added.
labels_n = labels[:n] # GB: Added.

# print images
imshow(torchvision.utils.make_grid(images_n.cpu()))
# print('Ground Truth: ', ' '.join('%5s' % classes[labels_n[j]] for j in range(n)))

outputs = model(images)

_, predicted = torch.max(outputs, 1)

print('Predicted:', '\n'.join('%5s' % classes[predicted[j]]
                              for j in range(n)))
# Out:
# Predicted: moe_szyslak
# marge_simpson
# krusty_the_clown
# krusty_the_clown
# krusty_the_clown
# moe_szyslak
# marge_simpson
# krusty_the_clown

# %% [markdown]
# ## The End
